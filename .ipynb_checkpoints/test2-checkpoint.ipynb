# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from rlglue import rl_glue as RLGlue
from agents import QLearningAgent, Differential_QLearningAgent,J_Differential_QLearningAgent # import agent
from environments import RiverSwim # import environment

# %%
np.random.seed(0)

agents = {
    "Q-learning": QLearningAgent,
}
env = RiverSwim
all_reward_sums = {} # Contains sum of rewards during episode
all_state_visits = {} # Contains state visit counts during the last 10 episodes
agent_info = {"num_actions": 2, "num_states": 6, "epsilon": 0.1, "step_size": 0.5}
env_info = {}
num_runs = 10 # The number of runs
num_episodes = 100 # The number of episodes in each run

discount_rates = [0.1, 0.5, 0.9]

for discount_rate in discount_rates:
    agent_info["discount"] = discount_rate
    
    all_reward_sums[discount_rate] = []
    all_state_visits[discount_rate] = []
    
    for run in tqdm(range(num_runs)):
        agent_info["seed"] = run
        rl_glue1 = RLGlue.RLGlue(env, agents["Q-learning"])
        rl_glue1.rl_init(agent_info, env_info)

        reward_sums = []
        state_visits = np.zeros(6)
        for episode in range(num_episodes):
            r_sum = 0
            
            # Runs an episode while keeping track of visited states
            state, action = rl_glue1.rl_start()
            state_visits[np.where(state == 1)[0][0]] += 1
            for i in range(0, 100):
                reward, state, action, is_terminal = rl_glue1.rl_step()
                r_sum += reward
                state_visits[np.where(state == 1)[0][0]] += 1
            reward_sums.append(r_sum)
            last_episode_total_reward = r_sum
            
        all_reward_sums[discount_rate].append(reward_sums)
        all_state_visits[discount_rate].append(state_visits)

# plot results
for discount_rate in discount_rates:
    plt.plot(np.mean(all_reward_sums[discount_rate], axis=0), label="γ: " + str(discount_rate))
plt.xlabel("Episodes")
plt.ylabel("Sum of\n rewards\n during\n episode",rotation=0, labelpad=40)
plt.legend()
plt.show()
# Out:
# 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# 100%|██████████| 10/10 [00:14<00:00,  1.44s/it]

# %%
agents = {
    "DifferentialQLearningAgent": Differential_QLearningAgent,
}

agent_info = {"num_actions": 2, "num_states": 6, "epsilon": 0.1, "step_size": 0.5, "beta": 0.01}

for algorithm in ["DifferentialQLearningAgent"]:
    
    all_reward_sums[algorithm] = []
    all_state_visits[algorithm] = []
    
    for run in tqdm(range(num_runs)):
        agent_info["seed"] = run
        rl_glue1 = RLGlue.RLGlue(env, agents["DifferentialQLearningAgent"])
        rl_glue1.rl_init(agent_info, env_info)

        reward_sums = []
        state_visits = np.zeros(6)
        for episode in range(num_episodes):
            r_sum = 0
            
            # Runs an episode while keeping track of visited states
            state, action = rl_glue1.rl_start()
            state_visits[np.where(state == 1)[0][0]] += 1
            for i in range(0, 100):
                reward, state, action, is_terminal = rl_glue1.rl_step()
                r_sum += reward
                state_visits[np.where(state == 1)[0][0]] += 1
            reward_sums.append(r_sum)
            last_episode_total_reward = r_sum
            
        all_reward_sums[algorithm].append(reward_sums)
        all_state_visits[algorithm].append(state_visits)

# plot results
for algorithm in ["DifferentialQLearningAgent"]:
    plt.plot(np.mean(all_reward_sums[algorithm], axis=0), label="" + str("Differential Q learning"))
plt.xlabel("Episodes")
plt.ylabel("Sum of\n rewards\n during\n episode",rotation=0, labelpad=40)
plt.legend()
plt.show()
# Out:
# 100%|██████████| 10/10 [00:13<00:00,  1.39s/it]

# %%
agents = {
    "JDifferentialQLearningAgent": J_Differential_QLearningAgent,
}


agent_info = {"num_actions": 2, "num_states": 6, "step_size": 0.5, "beta": 0.01}

for algorithm in ["JDifferentialQLearningAgent"]:
    
    all_reward_sums[algorithm] = []
    all_state_visits[algorithm] = []
    
    for run in tqdm(range(num_runs)):
        agent_info["seed"] = run
        rl_glue1 = RLGlue.RLGlue(env, agents["JDifferentialQLearningAgent"])
        rl_glue1.rl_init(agent_info, env_info)

        reward_sums = []
        state_visits = np.zeros(6)
        for episode in range(num_episodes):
            r_sum = 0
            
            # Runs an episode while keeping track of visited states
            state, action = rl_glue1.rl_start()
            state_visits[np.where(state == 1)[0][0]] += 1
            for i in range(0, 100):
                reward, state, action, is_terminal = rl_glue1.rl_step()
                r_sum += reward
                state_visits[np.where(state == 1)[0][0]] += 1
            reward_sums.append(r_sum)
            last_episode_total_reward = r_sum
            
        all_reward_sums[algorithm].append(reward_sums)
        all_state_visits[algorithm].append(state_visits)

# plot results
for algorithm in ["JDifferentialQLearningAgent"]:
    plt.plot(np.mean(all_reward_sums[algorithm], axis=0), label="" + str("J Differential Q learning"))
plt.xlabel("Episodes")
plt.ylabel("Sum of\n rewards\n during\n episode",rotation=0, labelpad=40)
plt.legend()
plt.show()
# Out:
# 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
